# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AC-01967'],
    
    'AD LIST NUMBER': ['999809'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS.*** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES.*** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.;OEM:3323-200, 0802-056"'],
}

#list all models
list_models = [
    
'400 2x4',
'400 2x4 Auto',
'400 4x4',
'400 4x4 ACT',
'400 4x4 Auto',
'400 4x4 Auto ACT',
'400 4x4 Auto LE',
'400 4x4 Auto MRP',
'400 4x4 Auto TBX',
'400 4x4 Auto TRV',
'400 4x4 Auto TRV Plus',
'400 4x4 Auto VP',
'400 4x4 VP',
'400 2x4 FIS',
'400 4x4 FIS',
'DVX 400',
'DVX 400 TS',
'400 4x4 MRP',
'400 Core',
'TRV 400 Core',
'TRV 400',
'400',
'Alterra 400',
'425',
'425i',
'425i SE',
'450 EFI H1 4x4 Auto',
'450 TRV',
'450 LTD',
'450',
'XC 450i',
'TRV 450i',
'TRV 450i GT',
'450i',
'450i GT',
'450 Core',
'XC 450',
'Alterra 450',
'500 4x4',
'500 4x4 Auto',
'500 4x4 Auto M4',
'500 4x4 Auto TRV',
'500 XT',
'500 Core',
'TRV 500 Core',
'TRV 500',
'500',
'XR 500',
'Alterra 500 XT',
'Alterra TRV 500',
'Alterra 500'



]

#Range of Years
years = list(range(2008, 2018))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make            Model Vendor Code                    Vendor Name  \
# 0    utv/atv          400 2x4        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1    utv/atv     400 2x4 Auto        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2    utv/atv          400 4x4        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3    utv/atv      400 4x4 ACT        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4    utv/atv     400 4x4 Auto        NACH  NACHMAN INTERNATIONAL CO. LTD
# ..       ...              ...         ...                            ...
# 505  utv/atv              500        NACH  NACHMAN INTERNATIONAL CO. LTD
# 506  utv/atv           XR 500        NACH  NACHMAN INTERNATIONAL CO. LTD
# 507  utv/atv   Alterra 500 XT        NACH  NACHMAN INTERNATIONAL CO. LTD
# 508  utv/atv  Alterra TRV 500        NACH  NACHMAN INTERNATIONAL CO. LTD
# 509  utv/atv      Alterra 500        NACH  NACHMAN INTERNATIONAL CO. LTD
#
#           MPN AD LIST NUMBER  \
# 0    AC-01967         999809
# ...

# %%
path_file = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\1.csv"
final_df.to_csv(path_file, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AC-01950'],
    
    'AD LIST NUMBER': ['999792'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS.*** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES.*** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.;OEM:327700001, 31100-F39-0002, 31120-004-000, 327700001, 420685638, 0180-032000, "'],
}


#list all models
list_models = [
    
'Sportsman 500 HO',
'Sportsman 500 HO RSE',
'Sportsman 500 HO Touring',
'Sportsman 500 HO Polaris Pursuite LE',
'Sportsman 500 HO DUSE',
'Sportsman 400',
'Sportsman 400 HO',
'Sportsman 400 4x4',
'Sportsman 400L',
'Sportsman 400 HO South Edition',
'Hawkeye 2x4',
'Hawkeye 4x4',
'Sportsman 500 EFI Touring',
'Sportsman 500 HO Touring',
'Sportsman Forest 500'


]

#Range of Years
years = list(range(2004, 2015))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                                 Model Vendor Code  \
# 0    utv/atv                      Sportsman 500 HO        NACH
# 1    utv/atv                  Sportsman 500 HO RSE        NACH
# 2    utv/atv              Sportsman 500 HO Touring        NACH
# 3    utv/atv  Sportsman 500 HO Polaris Pursuite LE        NACH
# 4    utv/atv                 Sportsman 500 HO DUSE        NACH
# ..       ...                                   ...         ...
# 160  utv/atv                           Hawkeye 2x4        NACH
# 161  utv/atv                           Hawkeye 4x4        NACH
# 162  utv/atv             Sportsman 500 EFI Touring        NACH
# 163  utv/atv              Sportsman 500 HO Touring        NACH
# 164  utv/atv                  Sportsman Forest 500        NACH
#
#                        Vendor Name       MPN AD LIST NUMBER  \
# 0    NACHMAN INTERNATIONAL CO. LTD  AC-01950         999792
# 1    NACHMAN INTERNATIONAL CO. LTD  AC-01950         999792
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\2.csv"
final_df.to_csv(file_path, index =False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AC-01951'],
    
    'AD LIST NUMBER': ['999793'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM:31120-HP5-601, 31120-HP5-A51, 31120-HM7-700, 31120-HM7-004, 31120-HM7-014,31120-HN0-671, 32101-38F00" '],
}


#list all models
list_models = [
    
'Sportsman 700 EFI',
'Sportsman 700 EFI X2',
'Sportsman 800 EFI',
'Sportsman 800 EFI HO',
'Sportsman 800 EFI Touring',
'Sportsman 800 EFI Deluxe',
'Sportsman 800 EFI X2 Deluxe',
'Sportsman 800 EFI X2',
'Sportsman 800 EFI 6x6 Big Boss',
'Ranger XP 700'

]

#Range of Years
years = list(range(2004, 2008))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make                           Model Vendor Code  \
# 0   utv/atv               Sportsman 700 EFI        NACH
# 1   utv/atv            Sportsman 700 EFI X2        NACH
# 2   utv/atv               Sportsman 800 EFI        NACH
# 3   utv/atv            Sportsman 800 EFI HO        NACH
# 4   utv/atv       Sportsman 800 EFI Touring        NACH
# 5   utv/atv        Sportsman 800 EFI Deluxe        NACH
# 6   utv/atv     Sportsman 800 EFI X2 Deluxe        NACH
# 7   utv/atv            Sportsman 800 EFI X2        NACH
# 8   utv/atv  Sportsman 800 EFI 6x6 Big Boss        NACH
# 9   utv/atv                   Ranger XP 700        NACH
# 10  utv/atv               Sportsman 700 EFI        NACH
# 11  utv/atv            Sportsman 700 EFI X2        NACH
# 12  utv/atv               Sportsman 800 EFI        NACH
# 13  utv/atv            Sportsman 800 EFI HO        NACH
# 14  utv/atv       Sportsman 800 EFI Touring        NACH
# 15  utv/atv        Sportsman 800 EFI Deluxe        NACH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\3.csv"
final_df.to_csv(file_path, index =False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AC-01952'],
    
    'AD LIST NUMBER': ['999794'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM:32101-19B10, 32101-19B30, 32101-45C00, 32101-48E00, 327700001, 31100-F39-0002, 31120-004-000, 327700001" '],
}


#list all models
list_models = [
    
'Ranger 500',
'Ranger 500 Crew',
'Ranger 500 Crew LE',
'Ranger 500 Crew Turbo Silver LE',
'Ranger 500 EFI',
'Ranger 500 EFI LE',
'Ranger 4x4 500',
'Ranger 4x4 500 EFI'
]

#Range of Years
years = list(range(2006, 2014))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make                            Model Vendor Code  \
# 0   utv/atv                       Ranger 500        NACH
# 1   utv/atv                  Ranger 500 Crew        NACH
# 2   utv/atv               Ranger 500 Crew LE        NACH
# 3   utv/atv  Ranger 500 Crew Turbo Silver LE        NACH
# 4   utv/atv                   Ranger 500 EFI        NACH
# ..      ...                              ...         ...
# 59  utv/atv  Ranger 500 Crew Turbo Silver LE        NACH
# 60  utv/atv                   Ranger 500 EFI        NACH
# 61  utv/atv                Ranger 500 EFI LE        NACH
# 62  utv/atv                   Ranger 4x4 500        NACH
# 63  utv/atv               Ranger 4x4 500 EFI        NACH
#
#                       Vendor Name       MPN AD LIST NUMBER  \
# 0   NACHMAN INTERNATIONAL CO. LTD  AC-01952         999794
# 1   NACHMAN INTERNATIONAL CO. LTD  AC-01952         999794
# 2   NACHMAN INTERNATIONAL CO. LTD  AC-01952         999794
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\4.csv"
final_df.to_csv(file_path, index =False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AC-01953'],
    
    'AD LIST NUMBER': ['999795'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM:327700001, 31100-F39-0002, 31120-004-000, 327700001" '],
}


#list all models
list_models = [

'Predator 50',
'Predator 500'

]

#Range of Years
years = list(range(2005, 2008))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#       Make         Model Vendor Code                    Vendor Name       MPN  \
# 0  utv/atv   Predator 50        NACH  NACHMAN INTERNATIONAL CO. LTD  AC-01953
# 1  utv/atv  Predator 500        NACH  NACHMAN INTERNATIONAL CO. LTD  AC-01953
# 2  utv/atv   Predator 50        NACH  NACHMAN INTERNATIONAL CO. LTD  AC-01953
# 3  utv/atv  Predator 500        NACH  NACHMAN INTERNATIONAL CO. LTD  AC-01953
# 4  utv/atv   Predator 50        NACH  NACHMAN INTERNATIONAL CO. LTD  AC-01953
# 5  utv/atv  Predator 500        NACH  NACHMAN INTERNATIONAL CO. LTD  AC-01953
#
#   AD LIST NUMBER                                       VENDOR NOTES  Year
# 0         999795  "*** AT-01450 ALSO FITS ON MC/ MX APPLICATION,...  2005
# 1         999795  "*** AT-01450 ALSO FITS ON MC/ MX APPLICATION,...  2005
# 2         999795  "*** AT-01450 ALSO FITS ON MC/ MX APPLICATION,...  2006
# 3         999795  "*** AT-01450 ALSO FITS ON MC/ MX APPLICATION,...  2006
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\5.csv"
final_df.to_csv(file_path, index =False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AC-01954'],
    
    'AD LIST NUMBER': ['999796'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM:327700001, 31100-F39-0002, 31120-004-000, 327700001, 420685630, 420685631, 420685632, 420685638, 0180-032000, 4013970, 4014402, 4014406, 4014839, 4015340, 21003-1214, 21003-1368, 2UJ-81410-00-00, 3087252,3089275, 31120-KBV-004, 31120-KV0-004,32101-19B10, 32101-19B30, 2101-45C00,32101-48E00, 3TB-81410-00-00" '],
}


#list all models
list_models = [

'Worker 335',
'Sportsman 335',
'Sportsman 400',
'Sportsman 400 HO',
'Sportsman 400 4x4',
'Sportsman 400L',
'Sportsman 400 HO South Edition',
'Magnum 425 2x4',
'Magnum 425 4x4',
'Magnum 425 6x6',
'Xplorer 500 4x4',
'Sportsman 500 4x4',
'Sportsman 500 6x6',
'Sportsman 500 EFI Touring',
'Sportsman 500 EFI X2',
'Sportsman 500 HO',
'Sportsman 500 EFI',
'Sportsman 500 EFI Deluxe',
'Sportsman 500 EFI X2 Deluxe',
'Sportsman 500 RSE',
'Sportsman 500 HO RSE',
'Sportsman 500 HO Touring',
'Sportsman 500 HO Polaris Pursuite LE',
'Sportsman 500 HO DUSE',
'Ranger 2x4 425',
'Ranger 4x4 500',
'Ranger 6x6 500',
'Ranger 2x4 500',
'Ranger 4x4 500 EFI',
'Ranger 6x6 700 EFI',
'Ranger 700 Crew',
'Ranger RZR 800',
'Ranger TM 650',
'Ranger XP 700',
'Ranger HD 700',
'Ranger RZR 800 S',
'Ranger RZR 170',
'Ranger 4x4 700 EFI',
'Ranger 4x4 400',
'Ranger EV',
'Ranger 800 Crew',
'Ranger 6x6 800',
'Ranger EV LSV',
'Ranger 800 XP',
'Ranger 800 XP EPS',
'Ranger RZR 800 EPS',
'Ranger 800 HD',
'Ranger 800 HD EPS',
'Ranger 500 Crew',
'Ranger 800 Crew EPS',
'Ranger Diesel',
'Ranger RZR 4 800 Gordon Edition',
'Ranger RZR 4 800 EPS Robby Gordon',
'Ranger RZR XP 900',
'Ranger RZR XP 900 LE',
'Ranger MVRS 700 4x4',
'Ranger MVRS 700 6x6',
'Ranger MVRS 800 6x6',
'Ranger MVRS 800 4x4',
'Ranger RZR 800 SW Military',
'Ranger RZR S Military',
'Ranger RZR 4 800 EPS Robby Gordon LE',
'Ranger Diesel Crew',
'Ranger RZR 800 S LE',
'Ranger 800 XP EPS LE',
'Ranger 800 Crew EPS LE',
'Ranger 800 XP LE',
'Ranger RZR 800 EPS LE',
'Ranger RZR 800 LE',
'Ranger 500 Crew Turbo Silver LE',
'Ranger RZR 570',
'Ranger 500 EFI',
'Ranger 500 EFI LE',
'Ranger RZR XP 4 900',
'Ranger RZR XP 4 900 EPS LE',
'Ranger RZR 4 800',
'Ranger RZR 570 EPS Trail LE',
'Ranger RZR 4 800 EPS LE',
'Ranger RZR XP 900 EPS Walker Evans LE',
'Ranger RZR XP 900 EPS LE',
'Ranger 500 Crew LE',
'Ranger 800 EFI Mid-Size',
'Ranger 800 EFI Mid-Size LE',
'Ranger 800 EFI',
'Ranger 800 EFI LE',
'Ranger 800 EFI EPS LE',
'Ranger 800 EFI EPS',
'Ranger 900 XP',
'Ranger 900 XP EPS',
'Ranger 900 XP EPS Browning LE',
'Ranger 900 XP EPS LE',
'Ranger 900 XP LE',
'Ranger 900 XP Bronze Mist LE',
'Ranger RZR XP 900 HO Jagged X Edition',
'Ranger RZR S 800 EPS LE',
'Ranger 570',
'Ranger 570 EPS LE',
'Ranger 800 EPS Mid-Size LE',
'Ranger 570 Crew',
'Ranger 570 Crew EPS LE',
'Ranger 900 Crew',
'Ranger 900 Crew EPS',
'Ranger 900 Crew EPS LE',
'Ranger 900 XP Deluxe',
'Ranger Diesel HST',
'Ranger Diesel HST Deluxe',
'Ranger ETX',
'Ranger 570 EPS',
'Ranger 900 XP EPS Northstar Edition',
'Ranger 900 XP EPS Hunter Deluxe Edition',
'Ranger 900 XP EPS Deluxe',
'Ranger 900 XP EPS Hunter Edition',
'Ranger 570 EPS Full-Size',
'Ranger 570 Full-Size',
'Ranger 570 Crew EPS',
'Ranger 570 Crew Full-Size',
'Ranger 570 Crew EPS Full-Size',
'Ranger 900-6 Crew',
'Ranger 900-6 Crew EPS',
'Ranger 570 EPS Hunter Edition',
'Ranger EV Li-Ion',
'Ranger XP 570',
'Ranger XP 570 EPS',
'Ranger XP 900',
'Ranger XP 900 EPS',
'Ranger XP 900 EPS Trail Edition',
'Ranger XP 900 EPS Hunter Deluxe Edition',
'Ranger XP 900 EPS Hunter Edition',
'Ranger XP 900 EPS High Lifter Edition',
'Ranger XP 900 EPS Northstar Edition',
'Ranger Crew 570-4',
'Ranger Crew 570-4 EPS',
'Ranger Crew 570-6',
'Ranger Crew 570-6 EPS',
'Ranger Crew 900-5',
'Ranger Crew 900-5 EPS',
'Ranger Crew 900-6',
'Ranger Crew 900-6 EPS',
'Ranger Crew Diesel',
'Ranger 500',
'Ranger Crew XP 900',
'Ranger Crew XP 900 EPS',
'Ranger Crew XP 1000 EPS',
'Ranger Crew XP 1000',
'Ranger Crew XP 1000 EPS High Lifter Edition',
'Ranger Crew XP 1000 EPS Northstar HVAC Edition',
'Ranger XP 1000 EPS Northstar HVAC Edition',
'Ranger XP 1000 EPS High Lifter Edition',
'Ranger XP 1000 EPS Ranch Edition',
'Ranger XP 1000 EPS Hunter Edition',
'Ranger XP 1000 EPS',
'Ranger XP 1000',
'Ranger 150 EFI',
'Ranger XP 1000 EPS Premium',
'Ranger Crew XP 1000 EPS Premium',
'Ranger Crew XP 1000 EPS 20th Anniversary',
'Ranger XP 1000 EPS 20th Anniversary',
'Ranger 1000',
'Ranger 1000 EPS',
'Ranger 1000 Premium',
'Ranger XP 1000 Premium',
'Ranger XP 1000 NorthStar Edition',
'Ranger XP 1000 High Lifter Edition',
'Ranger XP 1000 Texas Edition',
'Ranger Crew 570-4 Premium',
'Ranger Crew 1000',
'Ranger Crew 1000 EPS',
'Ranger Crew 1000 Premium',
'Ranger Crew XP 1000 Premium',
'Ranger Crew XP 1000 EPS NorthStar Edition',
'Ranger Crew XP 1000 High Lifter Edition',
'Ranger Crew XP 1000 Texas Edition',
'Ranger Crew XP 1000 NorthStar Ultimate',
'Ranger Crew XP 1000 NorthStar Edition Trail Boss',
'Ranger XP 1000 NorthStar Premium',
'Ranger Crew XP 1000 NorthStar Premium',
'Ranger XP 1000 NorthStar Edition Trail Boss',
'Ranger Crew XP 1000 Trail Boss',
'Ranger XP 1000 NorthStar Ultimate',
'Ranger 570 Premium',
'Ranger XP 1000 Trail Boss',
'Ranger SP 570',
'Ranger 1000 Premium + Winter Prep Package',
'Ranger SP 570 NorthStar Edition',
'Ranger Crew SP 570 NorthStar Edition',
'Ranger Crew SP 570',
'Ranger Crew 1000 Premium + Winter Prep Package',
'Ranger Crew 570 Full-Size',
'Ranger Crew XP 1000 Big Game Edition',
'Ranger SP 570 Premium',
'Ranger Crew XP 1000 NorthStar Big Game Edition',
'Ranger XP Kinetic Ultimate',
'Ranger XP 1000 Waterfowl Edition',
'Ranger Crew SP 570 Premium',
'Ranger Crew XP 1000 Waterfowl Edition',
'Ranger XP 1000 Big Game Edition',
'Ranger XP Kinetic Premium'


]

#Range of Years
years = list(range(1995, 2018))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#          Make                                  Model Vendor Code  \
# 0     utv/atv                             Worker 335        NACH
# 1     utv/atv                          Sportsman 335        NACH
# 2     utv/atv                          Sportsman 400        NACH
# 3     utv/atv                       Sportsman 400 HO        NACH
# 4     utv/atv                      Sportsman 400 4x4        NACH
# ...       ...                                    ...         ...
# 4526  utv/atv       Ranger XP 1000 Waterfowl Edition        NACH
# 4527  utv/atv             Ranger Crew SP 570 Premium        NACH
# 4528  utv/atv  Ranger Crew XP 1000 Waterfowl Edition        NACH
# 4529  utv/atv        Ranger XP 1000 Big Game Edition        NACH
# 4530  utv/atv              Ranger XP Kinetic Premium        NACH
#
#                         Vendor Name       MPN AD LIST NUMBER  \
# 0     NACHMAN INTERNATIONAL CO. LTD  AC-01954         999796
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\6.csv"
final_df.to_csv(file_path, index =False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AC-01956'],
    
    'AD LIST NUMBER': ['999798'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 0802-073, 420685630, 420685631, 420685632, 420685634, 420685638, 420686365, 420686363, 4011399, 4011982, 4014034, 4013970, 4014402, 4014406, 4014839, 4015340, 3084974, 3086860, 327700001, 31100-F39-0002, 31120-004-000, 327700001, 21003-0092, 21003-1359, K2100-31359, 32101-31G01, 32101-31G02" '],}


#list all models
list_models = [

'Outfitter',
'Conquest 8x8 Outfitter XTi',
'Conquest 8x8 Outfitter XTi-Z',



]

#Range of Years
years = list(range(2012, 2015))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#       Make                         Model Vendor Code  \
# 0  utv/atv                     Outfitter        NACH
# 1  utv/atv    Conquest 8x8 Outfitter XTi        NACH
# 2  utv/atv  Conquest 8x8 Outfitter XTi-Z        NACH
# 3  utv/atv                     Outfitter        NACH
# 4  utv/atv    Conquest 8x8 Outfitter XTi        NACH
# 5  utv/atv  Conquest 8x8 Outfitter XTi-Z        NACH
# 6  utv/atv                     Outfitter        NACH
# 7  utv/atv    Conquest 8x8 Outfitter XTi        NACH
# 8  utv/atv  Conquest 8x8 Outfitter XTi-Z        NACH
#
#                      Vendor Name       MPN AD LIST NUMBER  \
# 0  NACHMAN INTERNATIONAL CO. LTD  AC-01956         999798
# 1  NACHMAN INTERNATIONAL CO. LTD  AC-01956         999798
# 2  NACHMAN INTERNATIONAL CO. LTD  AC-01956         999798
# 3  NACHMAN INTERNATIONAL CO. LTD  AC-01956         999798
# 4  NACHMAN INTERNATIONAL CO. LTD  AC-01956         999798
# 5  NACHMAN INTERNATIONAL CO. LTD  AC-01956         999798
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\7.csv"
final_df.to_csv(file_path, index =False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AC-01957'],
    
    'AD LIST NUMBER': ['999799'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 5UH-81410-00, B16-H1410-00 " '],}


#list all models
list_models = [

'YFM250 Bear Tracker',
'YFM250 Big Bear',
'YFM250 Bruin',
'YFM250 Raptor',
'YFM250 Raptor SE',
'YFM250 Raptor SE Custom'



]

#Range of Years
years = list(range(2001, 2010))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make                    Model Vendor Code  \
# 0   utv/atv      YFM250 Bear Tracker        NACH
# 1   utv/atv          YFM250 Big Bear        NACH
# 2   utv/atv             YFM250 Bruin        NACH
# 3   utv/atv            YFM250 Raptor        NACH
# 4   utv/atv         YFM250 Raptor SE        NACH
# 5   utv/atv  YFM250 Raptor SE Custom        NACH
# 6   utv/atv      YFM250 Bear Tracker        NACH
# 7   utv/atv          YFM250 Big Bear        NACH
# 8   utv/atv             YFM250 Bruin        NACH
# 9   utv/atv            YFM250 Raptor        NACH
# 10  utv/atv         YFM250 Raptor SE        NACH
# 11  utv/atv  YFM250 Raptor SE Custom        NACH
# 12  utv/atv      YFM250 Bear Tracker        NACH
# 13  utv/atv          YFM250 Big Bear        NACH
# 14  utv/atv             YFM250 Bruin        NACH
# 15  utv/atv            YFM250 Raptor        NACH
# 16  utv/atv         YFM250 Raptor SE        NACH
# 17  utv/atv  YFM250 Raptor SE Custom        NACH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\8.csv"
final_df.to_csv(file_path, index =False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AC-01958'],
    
    'AD LIST NUMBER': ['999800'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 5TG-81410-00, 5TG-81410-01, 5TG-81410-02, 5TG-81410-03 " '],}


#list all models
list_models = [

'YYFM350F Wolverine 4x4'

]

#Range of Years
years = list(range(1995, 2000))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#       Make                   Model Vendor Code                    Vendor Name  \
# 0  utv/atv  YYFM350F Wolverine 4x4        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1  utv/atv  YYFM350F Wolverine 4x4        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2  utv/atv  YYFM350F Wolverine 4x4        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3  utv/atv  YYFM350F Wolverine 4x4        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4  utv/atv  YYFM350F Wolverine 4x4        NACH  NACHMAN INTERNATIONAL CO. LTD
#
#         MPN AD LIST NUMBER                                       VENDOR NOTES  \
# 0  AC-01958         999800  "*** AT-01450 ALSO FITS ON MC/ MX APPLICATION,...
# 1  AC-01958         999800  "*** AT-01450 ALSO FITS ON MC/ MX APPLICATION,...
# 2  AC-01958         999800  "*** AT-01450 ALSO FITS ON MC/ MX APPLICATION,...
# 3  AC-01958         999800  "*** AT-01450 ALSO FITS ON MC/ MX APPLICATION,...
# 4  AC-01958         999800  "*** AT-01450 ALSO FITS ON MC/ MX APPLICATION,...
#
#    Year
# 0  1995
# 1  1996
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\9.csv"
final_df.to_csv(file_path, index =False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AC-01959'],
    
    'AD LIST NUMBER': ['999801'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 28P-81410-00, 28P-81410-01, 3B4-81410-00 " '],}


#list all models
list_models = [

'YFM700 Raptor'

]

#Range of Years
years = list(range(2006, 2021))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make          Model Vendor Code                    Vendor Name  \
# 0   utv/atv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1   utv/atv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2   utv/atv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3   utv/atv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4   utv/atv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 5   utv/atv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 6   utv/atv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 7   utv/atv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 8   utv/atv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 9   utv/atv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 10  utv/atv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 11  utv/atv  YFM700 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\10.csv"
final_df.to_csv(file_path, index =False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AC-01960'],
    
    'AD LIST NUMBER': ['999802'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 1P0-H1410-00, 4XE-81410-00, 5LP-81410-00, 5LP-81410-01, 5LP-81410-02 " '],}


#list all models
list_models = [

'YXE70 Wolverine R-Spec',
'YXE70 Wolverine R-Spec EPS',
'YXE70 Wolverine',
'YXE70 Wolverine R-Spec EPS SE',
'YXE70 Wolverine EPS'

]

#Range of Years
years = list(range(2016, 2019))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make                          Model Vendor Code  \
# 0   utv/atv         YXE70 Wolverine R-Spec        NACH
# 1   utv/atv     YXE70 Wolverine R-Spec EPS        NACH
# 2   utv/atv                YXE70 Wolverine        NACH
# 3   utv/atv  YXE70 Wolverine R-Spec EPS SE        NACH
# 4   utv/atv            YXE70 Wolverine EPS        NACH
# 5   utv/atv         YXE70 Wolverine R-Spec        NACH
# 6   utv/atv     YXE70 Wolverine R-Spec EPS        NACH
# 7   utv/atv                YXE70 Wolverine        NACH
# 8   utv/atv  YXE70 Wolverine R-Spec EPS SE        NACH
# 9   utv/atv            YXE70 Wolverine EPS        NACH
# 10  utv/atv         YXE70 Wolverine R-Spec        NACH
# 11  utv/atv     YXE70 Wolverine R-Spec EPS        NACH
# 12  utv/atv                YXE70 Wolverine        NACH
# 13  utv/atv  YXE70 Wolverine R-Spec EPS SE        NACH
# 14  utv/atv            YXE70 Wolverine EPS        NACH
#
#                       Vendor Name       MPN AD LIST NUMBER  \
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\11.csv"
final_df.to_csv(file_path, index =False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AC-01961'],
    
    'AD LIST NUMBER': ['999803'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 4010911, 4011399, 4011982, 4014034 " '],}


#list all models
list_models = [

'Wildcat 1000',
'Wildcat 1000 LTD',
'Wildcat 4 1000',
'Wildcat 4X',
'Wildcat 4 Limited',
'Wildcat 4X Limited',
'Wildcat 4X LTD',
'Wildcat X 1000',
'Wildcat X Limited',
'Wildcat X',
'Wildcat X SE',
'Wildcat X LTD',
'Wildcat XX',
'Wildcat XX LTD',
'Wildcat XX SE'

]

#Range of Years
years = list(range(2012, 2020))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make              Model Vendor Code                    Vendor Name  \
# 0    utv/atv       Wildcat 1000        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1    utv/atv   Wildcat 1000 LTD        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2    utv/atv     Wildcat 4 1000        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3    utv/atv         Wildcat 4X        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4    utv/atv  Wildcat 4 Limited        NACH  NACHMAN INTERNATIONAL CO. LTD
# ..       ...                ...         ...                            ...
# 115  utv/atv       Wildcat X SE        NACH  NACHMAN INTERNATIONAL CO. LTD
# 116  utv/atv      Wildcat X LTD        NACH  NACHMAN INTERNATIONAL CO. LTD
# 117  utv/atv         Wildcat XX        NACH  NACHMAN INTERNATIONAL CO. LTD
# 118  utv/atv     Wildcat XX LTD        NACH  NACHMAN INTERNATIONAL CO. LTD
# 119  utv/atv      Wildcat XX SE        NACH  NACHMAN INTERNATIONAL CO. LTD
#
#           MPN AD LIST NUMBER  \
# 0    AC-01961         999803
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\12.csv"
final_df.to_csv(file_path, index =False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AC-01962'],
    
    'AD LIST NUMBER': ['999804'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 420685634 " '],}


#list all models
list_models = [

'TRX350',
'TRX350D',
'TRX350FE FourTrax Rancher 4x4 ES',
'TRX350FM FourTrax Rancher 4X4',
'TRX350TE FourTrax Rancher ES',
'TRX350TM FourTrax Rancher'
]

#Range of Years
years = list(range(2000, 2007))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make                             Model Vendor Code  \
# 0   utv/atv                            TRX350        NACH
# 1   utv/atv                           TRX350D        NACH
# 2   utv/atv  TRX350FE FourTrax Rancher 4x4 ES        NACH
# 3   utv/atv     TRX350FM FourTrax Rancher 4X4        NACH
# 4   utv/atv      TRX350TE FourTrax Rancher ES        NACH
# 5   utv/atv         TRX350TM FourTrax Rancher        NACH
# 6   utv/atv                            TRX350        NACH
# 7   utv/atv                           TRX350D        NACH
# 8   utv/atv  TRX350FE FourTrax Rancher 4x4 ES        NACH
# 9   utv/atv     TRX350FM FourTrax Rancher 4X4        NACH
# 10  utv/atv      TRX350TE FourTrax Rancher ES        NACH
# 11  utv/atv         TRX350TM FourTrax Rancher        NACH
# 12  utv/atv                            TRX350        NACH
# 13  utv/atv                           TRX350D        NACH
# 14  utv/atv  TRX350FE FourTrax Rancher 4x4 ES        NACH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\13.csv"
final_df.to_csv(file_path, index =False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AC-01963'],
    
    'AD LIST NUMBER': ['999805'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 420686365 " '],}


#list all models
list_models = [

'KVF750 Brute Force 4x4i',
'KVF750 Brute Force 4x4i EPS',
'KVF750 Brute Force 4x4i EPS Camo',
'KRF750 Teryx 4x4',
'KRF750 Teryx FI 4x4 LE',
'KRF750 Teryx NRA Outdoors',
'KRF750 Teryx FI 4x4 LE Sport',
'KRF750 Teryx FI 4x4 Sport',
'KRF750 Teryx FI 4x4',
'KRF750 Teryx FI 4x4 LE SGE',
'KRF750 Teryx FI 4x4 LE Camo'
    
]

#Range of Years
years = list(range(2008, 2013))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make                             Model Vendor Code  \
# 0   utv/atv           KVF750 Brute Force 4x4i        NACH
# 1   utv/atv       KVF750 Brute Force 4x4i EPS        NACH
# 2   utv/atv  KVF750 Brute Force 4x4i EPS Camo        NACH
# 3   utv/atv                  KRF750 Teryx 4x4        NACH
# 4   utv/atv            KRF750 Teryx FI 4x4 LE        NACH
# 5   utv/atv         KRF750 Teryx NRA Outdoors        NACH
# 6   utv/atv      KRF750 Teryx FI 4x4 LE Sport        NACH
# 7   utv/atv         KRF750 Teryx FI 4x4 Sport        NACH
# 8   utv/atv               KRF750 Teryx FI 4x4        NACH
# 9   utv/atv        KRF750 Teryx FI 4x4 LE SGE        NACH
# 10  utv/atv       KRF750 Teryx FI 4x4 LE Camo        NACH
# 11  utv/atv           KVF750 Brute Force 4x4i        NACH
# 12  utv/atv       KVF750 Brute Force 4x4i EPS        NACH
# 13  utv/atv  KVF750 Brute Force 4x4i EPS Camo        NACH
# 14  utv/atv                  KRF750 Teryx 4x4        NACH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\14.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AC-01964'],
    
    'AD LIST NUMBER': ['999806'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 420685630, 420685631, 420685632 " '],}


#list all models
list_models = [

'KRF750 Teryx 4x4',
'KRF750 Teryx FI 4x4 LE',
'KRF750 Teryx NRA Outdoors',
'KRF750 Teryx FI 4x4 LE Sport',
'KRF750 Teryx FI 4x4 Sport',
'KRF750 Teryx FI 4x4',
'KRF750 Teryx FI 4x4 LE SGE',
'KRF750 Teryx FI 4x4 LE Camo'
    
]

#Range of Years
years = list(range(2013, 2014))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#       Make                         Model Vendor Code  \
# 0  utv/atv              KRF750 Teryx 4x4        NACH
# 1  utv/atv        KRF750 Teryx FI 4x4 LE        NACH
# 2  utv/atv     KRF750 Teryx NRA Outdoors        NACH
# 3  utv/atv  KRF750 Teryx FI 4x4 LE Sport        NACH
# 4  utv/atv     KRF750 Teryx FI 4x4 Sport        NACH
# 5  utv/atv           KRF750 Teryx FI 4x4        NACH
# 6  utv/atv    KRF750 Teryx FI 4x4 LE SGE        NACH
# 7  utv/atv   KRF750 Teryx FI 4x4 LE Camo        NACH
#
#                      Vendor Name       MPN AD LIST NUMBER  \
# 0  NACHMAN INTERNATIONAL CO. LTD  AC-01964         999806
# 1  NACHMAN INTERNATIONAL CO. LTD  AC-01964         999806
# 2  NACHMAN INTERNATIONAL CO. LTD  AC-01964         999806
# 3  NACHMAN INTERNATIONAL CO. LTD  AC-01964         999806
# 4  NACHMAN INTERNATIONAL CO. LTD  AC-01964         999806
# 5  NACHMAN INTERNATIONAL CO. LTD  AC-01964         999806
# 6  NACHMAN INTERNATIONAL CO. LTD  AC-01964         999806
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\15.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AC-01965'],
    
    'AD LIST NUMBER': ['999807'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 420685630, 420685631, 420685632, 420685634 " '],}


#list all models
list_models = [

'TRX450ER Electric Start',
'TRX450FE FourTrax Foreman ES',
'TRX450FM FourTrax Foreman S',
'TRX450R'
    
]

#Range of Years
years = list(range(1995, 2005))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make                         Model Vendor Code  \
# 0   utv/atv       TRX450ER Electric Start        NACH
# 1   utv/atv  TRX450FE FourTrax Foreman ES        NACH
# 2   utv/atv   TRX450FM FourTrax Foreman S        NACH
# 3   utv/atv                       TRX450R        NACH
# 4   utv/atv       TRX450ER Electric Start        NACH
# 5   utv/atv  TRX450FE FourTrax Foreman ES        NACH
# 6   utv/atv   TRX450FM FourTrax Foreman S        NACH
# 7   utv/atv                       TRX450R        NACH
# 8   utv/atv       TRX450ER Electric Start        NACH
# 9   utv/atv  TRX450FE FourTrax Foreman ES        NACH
# 10  utv/atv   TRX450FM FourTrax Foreman S        NACH
# 11  utv/atv                       TRX450R        NACH
# 12  utv/atv       TRX450ER Electric Start        NACH
# 13  utv/atv  TRX450FE FourTrax Foreman ES        NACH
# 14  utv/atv   TRX450FM FourTrax Foreman S        NACH
# 15  utv/atv                       TRX450R        NACH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\16.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AC-01966'],
    
    'AD LIST NUMBER': ['999808'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 0802-041, 4010911,4010901, 4014839 " '],}


#list all models
list_models = [

'TBX 700 LTD',
'TBX 700i GT',
'TBX 700 XT',
'TBX 700',
'TBX 700 SE',
'Alterra TBX 700',
'TRV 700i GT',
'TRV 700i Cruiser',
'TRV 700 LTD',
'TRV 700 XT',
'TRV 700 SE',
'Alterra TRV 700 XT',
'Alterra TRV 700',
'Thundercat 1000 4x4 Auto',
'Prowler XTZ 1000 H2 EFI',
'Prowler XTZ 1000 Baja',
'1000 TRV Cruiser',
'SBS 1000',
'Thundercat 1000 4x4 Auto LE',
'1000 EFI H2 4x4 Auto Mud Pro',
'1000 EFI H2 4x4 Auto TRV',
'Prowler XTZ 1000',
'1000 LTD',
'MudPro 1000',
'TRV 1000i Cruiser',
'TRV 1000i GT',
'1000i GT',
'MudPro 1000 LTD',
'Wildcat 1000',
'Prowler XTZ 1000i',
'Wildcat 1000 LTD',
'1000 XT',
'TRV 1000 LTD',
'Wildcat 4 1000',
'Wildcat X 1000',
'TRV 1000 XT',
'Prowler XT 1000',
'Alterra TRV 1000 XT',
'MudPro 1000 SE',
'Prowler 1000 XT',
'Prowler 550',
'Prowler 700 XT'
]

#Range of Years
years = list(range(2008, 2015))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                Model Vendor Code                    Vendor Name  \
# 0    utv/atv          TBX 700 LTD        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1    utv/atv          TBX 700i GT        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2    utv/atv           TBX 700 XT        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3    utv/atv              TBX 700        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4    utv/atv           TBX 700 SE        NACH  NACHMAN INTERNATIONAL CO. LTD
# ..       ...                  ...         ...                            ...
# 289  utv/atv  Alterra TRV 1000 XT        NACH  NACHMAN INTERNATIONAL CO. LTD
# 290  utv/atv       MudPro 1000 SE        NACH  NACHMAN INTERNATIONAL CO. LTD
# 291  utv/atv      Prowler 1000 XT        NACH  NACHMAN INTERNATIONAL CO. LTD
# 292  utv/atv          Prowler 550        NACH  NACHMAN INTERNATIONAL CO. LTD
# 293  utv/atv       Prowler 700 XT        NACH  NACHMAN INTERNATIONAL CO. LTD
#
#           MPN AD LIST NUMBER  \
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\17.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AC-01968'],
    
    'AD LIST NUMBER': ['999810'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 3089249, 3089546, 3089965 " '],}


#list all models
list_models = [


'LT-A450X KingQuad AXi 4x4',
'LT-A500F QuadMaster',
'LT-A500F Vinson 500 4x4 Auto',
'LT-A500 KingQuad AXi',
'LT-A500 KingQuad AXi Power Steering',
'LT-A500 KingQuad AXi Power Steering SE',
'LT-A500 KingQuad AXi Power Steering SE Rugged',
'LT-A500 KingQuad AXi Power Steering SE+',
'LT-A500 KingQuad AXi Power Steering Rugged'


]

#Range of Years
years = list(range(2007, 2019))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                                          Model Vendor Code  \
# 0    utv/atv                      LT-A450X KingQuad AXi 4x4        NACH
# 1    utv/atv                            LT-A500F QuadMaster        NACH
# 2    utv/atv                   LT-A500F Vinson 500 4x4 Auto        NACH
# 3    utv/atv                           LT-A500 KingQuad AXi        NACH
# 4    utv/atv            LT-A500 KingQuad AXi Power Steering        NACH
# ..       ...                                            ...         ...
# 103  utv/atv            LT-A500 KingQuad AXi Power Steering        NACH
# 104  utv/atv         LT-A500 KingQuad AXi Power Steering SE        NACH
# 105  utv/atv  LT-A500 KingQuad AXi Power Steering SE Rugged        NACH
# 106  utv/atv        LT-A500 KingQuad AXi Power Steering SE+        NACH
# 107  utv/atv     LT-A500 KingQuad AXi Power Steering Rugged        NACH
#
#                        Vendor Name       MPN AD LIST NUMBER  \
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\18.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AC-01969'],
    
    'AD LIST NUMBER': ['999811'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 3084974, 3086860 " '],}


#list all models
list_models = [

'LT-Z400 QuadSport Z',
'LT-Z400 QuadSport Z LE'


]

#Range of Years
years = list(range(2009, 2015))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make                   Model Vendor Code  \
# 0   utv/atv     LT-Z400 QuadSport Z        NACH
# 1   utv/atv  LT-Z400 QuadSport Z LE        NACH
# 2   utv/atv     LT-Z400 QuadSport Z        NACH
# 3   utv/atv  LT-Z400 QuadSport Z LE        NACH
# 4   utv/atv     LT-Z400 QuadSport Z        NACH
# 5   utv/atv  LT-Z400 QuadSport Z LE        NACH
# 6   utv/atv     LT-Z400 QuadSport Z        NACH
# 7   utv/atv  LT-Z400 QuadSport Z LE        NACH
# 8   utv/atv     LT-Z400 QuadSport Z        NACH
# 9   utv/atv  LT-Z400 QuadSport Z LE        NACH
# 10  utv/atv     LT-Z400 QuadSport Z        NACH
# 11  utv/atv  LT-Z400 QuadSport Z LE        NACH
#
#                       Vendor Name       MPN AD LIST NUMBER  \
# 0   NACHMAN INTERNATIONAL CO. LTD  AC-01969         999811
# 1   NACHMAN INTERNATIONAL CO. LTD  AC-01969         999811
# 2   NACHMAN INTERNATIONAL CO. LTD  AC-01969         999811
# 3   NACHMAN INTERNATIONAL CO. LTD  AC-01969         999811
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\19.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AC-01970'],
    
    'AD LIST NUMBER': ['999812'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 420296907, 420684850, 420685920 " '],}


#list all models
list_models = [

'LDS 650 X'



]

#Range of Years
years = list(range(2000, 2008))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#       Make      Model Vendor Code                    Vendor Name       MPN  \
# 0  utv/atv  LDS 650 X        NACH  NACHMAN INTERNATIONAL CO. LTD  AC-01970
# 1  utv/atv  LDS 650 X        NACH  NACHMAN INTERNATIONAL CO. LTD  AC-01970
# 2  utv/atv  LDS 650 X        NACH  NACHMAN INTERNATIONAL CO. LTD  AC-01970
# 3  utv/atv  LDS 650 X        NACH  NACHMAN INTERNATIONAL CO. LTD  AC-01970
# 4  utv/atv  LDS 650 X        NACH  NACHMAN INTERNATIONAL CO. LTD  AC-01970
# 5  utv/atv  LDS 650 X        NACH  NACHMAN INTERNATIONAL CO. LTD  AC-01970
# 6  utv/atv  LDS 650 X        NACH  NACHMAN INTERNATIONAL CO. LTD  AC-01970
# 7  utv/atv  LDS 650 X        NACH  NACHMAN INTERNATIONAL CO. LTD  AC-01970
#
#   AD LIST NUMBER                                       VENDOR NOTES  Year
# 0         999812  "*** AT-01450 ALSO FITS ON MC/ MX APPLICATION,...  2000
# 1         999812  "*** AT-01450 ALSO FITS ON MC/ MX APPLICATION,...  2001
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\20.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AC-01971'],
    
    'AD LIST NUMBER': ['999813'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 3089249, 3089546, 3089965, 3430-058 " '],}


#list all models
list_models = [

'500 4x4',
'500 4x4 Auto',
'500 4x4 Auto LE',
'500 4x4 Auto M4',
'500 4x4 Auto TBX',
'500 4x4 Auto TRV',
'500 4x4 Auto MRP',
'500 4x4 MRP',
'LT-A500F Vinson 500 4x4 Auto'



]

#Range of Years
years = list(range(2003, 2010))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make                         Model Vendor Code  \
# 0   utv/atv                       500 4x4        NACH
# 1   utv/atv                  500 4x4 Auto        NACH
# 2   utv/atv               500 4x4 Auto LE        NACH
# 3   utv/atv               500 4x4 Auto M4        NACH
# 4   utv/atv              500 4x4 Auto TBX        NACH
# ..      ...                           ...         ...
# 58  utv/atv              500 4x4 Auto TBX        NACH
# 59  utv/atv              500 4x4 Auto TRV        NACH
# 60  utv/atv              500 4x4 Auto MRP        NACH
# 61  utv/atv                   500 4x4 MRP        NACH
# 62  utv/atv  LT-A500F Vinson 500 4x4 Auto        NACH
#
#                       Vendor Name       MPN AD LIST NUMBER  \
# 0   NACHMAN INTERNATIONAL CO. LTD  AC-01971         999813
# 1   NACHMAN INTERNATIONAL CO. LTD  AC-01971         999813
# 2   NACHMAN INTERNATIONAL CO. LTD  AC-01971         999813
# 3   NACHMAN INTERNATIONAL CO. LTD  AC-01971         999813
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\21.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AC-01972'],
    
    'AD LIST NUMBER': ['999814'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 3089249, 3089546, 3089965 " '],}


#list all models
list_models = [

'LT-R450 QuadRacer'




]

#Range of Years
years = list(range(2006, 2010))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#       Make              Model Vendor Code                    Vendor Name  \
# 0  utv/atv  LT-R450 QuadRacer        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1  utv/atv  LT-R450 QuadRacer        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2  utv/atv  LT-R450 QuadRacer        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3  utv/atv  LT-R450 QuadRacer        NACH  NACHMAN INTERNATIONAL CO. LTD
#
#         MPN AD LIST NUMBER                                       VENDOR NOTES  \
# 0  AC-01972         999814  "*** AT-01450 ALSO FITS ON MC/ MX APPLICATION,...
# 1  AC-01972         999814  "*** AT-01450 ALSO FITS ON MC/ MX APPLICATION,...
# 2  AC-01972         999814  "*** AT-01450 ALSO FITS ON MC/ MX APPLICATION,...
# 3  AC-01972         999814  "*** AT-01450 ALSO FITS ON MC/ MX APPLICATION,...
#
#    Year
# 0  2006
# 1  2007
# 2  2008
# 3  2009

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\22.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AC-01973'],
    
    'AD LIST NUMBER': ['999815'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 31120-HN5-M02, 31120-HN5-671, 31120-HN5-672, 31120-HN5-M01, 31120-HP5-601, 31120-HP5-A51, 31120-HN2-A21, 31120-HP5-601, 31120-HP5-A51, 31120-HN2-A21 " '],}


#list all models
list_models = [

'Sportsman 600',
'Sportsman 700',
'Sportsman 700 EFI',
'Sportsman 700 EFI X2',
'Sportsman 700 MV',
'Sportsman MV7'




]

#Range of Years
years = list(range(2004, 2007))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make                 Model Vendor Code                    Vendor Name  \
# 0   utv/atv         Sportsman 600        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1   utv/atv         Sportsman 700        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2   utv/atv     Sportsman 700 EFI        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3   utv/atv  Sportsman 700 EFI X2        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4   utv/atv      Sportsman 700 MV        NACH  NACHMAN INTERNATIONAL CO. LTD
# 5   utv/atv         Sportsman MV7        NACH  NACHMAN INTERNATIONAL CO. LTD
# 6   utv/atv         Sportsman 600        NACH  NACHMAN INTERNATIONAL CO. LTD
# 7   utv/atv         Sportsman 700        NACH  NACHMAN INTERNATIONAL CO. LTD
# 8   utv/atv     Sportsman 700 EFI        NACH  NACHMAN INTERNATIONAL CO. LTD
# 9   utv/atv  Sportsman 700 EFI X2        NACH  NACHMAN INTERNATIONAL CO. LTD
# 10  utv/atv      Sportsman 700 MV        NACH  NACHMAN INTERNATIONAL CO. LTD
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\23.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AT-01444'],
    
    'AD LIST NUMBER': ['127869'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 3089249, 3089546, 3089965 " '],}


#list all models
list_models = [



'LT-A400F Eiger 4x4 Auto',
'LT-A400F KingQuad AS',
'LT-A400F KingQuad ASi',
'LT-A400F KingQuad ASi LE',
'LT-A400F KingQuad ASi SE',
'LT-A400F KingQuad ASi+',
'LT-A400F KingQuad ASi SE+'




]

#Range of Years
years = list(range(2008, 2022))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make                      Model Vendor Code  \
# 0   utv/atv    LT-A400F Eiger 4x4 Auto        NACH
# 1   utv/atv       LT-A400F KingQuad AS        NACH
# 2   utv/atv      LT-A400F KingQuad ASi        NACH
# 3   utv/atv   LT-A400F KingQuad ASi LE        NACH
# 4   utv/atv   LT-A400F KingQuad ASi SE        NACH
# ..      ...                        ...         ...
# 93  utv/atv      LT-A400F KingQuad ASi        NACH
# 94  utv/atv   LT-A400F KingQuad ASi LE        NACH
# 95  utv/atv   LT-A400F KingQuad ASi SE        NACH
# 96  utv/atv     LT-A400F KingQuad ASi+        NACH
# 97  utv/atv  LT-A400F KingQuad ASi SE+        NACH
#
#                       Vendor Name       MPN AD LIST NUMBER  \
# 0   NACHMAN INTERNATIONAL CO. LTD  AT-01444         127869
# 1   NACHMAN INTERNATIONAL CO. LTD  AT-01444         127869
# 2   NACHMAN INTERNATIONAL CO. LTD  AT-01444         127869
# 3   NACHMAN INTERNATIONAL CO. LTD  AT-01444         127869
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\24.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AT-01445'],
    
    'AD LIST NUMBER': ['127870'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 420296907, 420684850, 420685920, 420685630, 420685631, 420685632 " '],}


#list all models
list_models = [




'TRX420FE FourTrax Rancher 4X4 ES',
'TRX420FM FourTrax Rancher 4X4',
'TRX420TE FourTrax Rancher ES',
'TRX420TM FourTrax Rancher',
'TRX420FPA Rancher AT 4x4 w/ Power Steering',
'TRX420FPE Rancher ES 4x4 w/ Power Steering',
'TRX420FPM Rancher 4x4 w/ Power Steering',
'TRX420FA Rancher AT',
'TRX420TM1 FourTrax Rancher',
'TRX420TE1 FourTrax Rancher ES',
'TRX420FM1 FourTrax Rancher 4x4',
'TRX420FE1 FourTrax Rancher 4x4 ES',
'TRX420FM2 FourTrax Rancher 4x4 with EPS',
'TRX420FA2 FourTrax Rancher 4x4 Auto DCT with EPS',
'TRX420FA1 FourTrax Rancher 4x4 Auto DCT',
'TRX420FA5 FourTrax Rancher 4x4 Auto DCT IRS',
'TRX420FA6 FourTrax Rancher 4x4 Auto DCT IRS EPS'



]

#Range of Years
years = list(range(2007, 2014))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                                             Model Vendor Code  \
# 0    utv/atv                  TRX420FE FourTrax Rancher 4X4 ES        NACH
# 1    utv/atv                     TRX420FM FourTrax Rancher 4X4        NACH
# 2    utv/atv                      TRX420TE FourTrax Rancher ES        NACH
# 3    utv/atv                         TRX420TM FourTrax Rancher        NACH
# 4    utv/atv        TRX420FPA Rancher AT 4x4 w/ Power Steering        NACH
# ..       ...                                               ...         ...
# 114  utv/atv           TRX420FM2 FourTrax Rancher 4x4 with EPS        NACH
# 115  utv/atv  TRX420FA2 FourTrax Rancher 4x4 Auto DCT with EPS        NACH
# 116  utv/atv           TRX420FA1 FourTrax Rancher 4x4 Auto DCT        NACH
# 117  utv/atv       TRX420FA5 FourTrax Rancher 4x4 Auto DCT IRS        NACH
# 118  utv/atv   TRX420FA6 FourTrax Rancher 4x4 Auto DCT IRS EPS        NACH
#
#                        Vendor Name       MPN AD LIST NUMBER  \
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\25.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AT-01446'],
    
    'AD LIST NUMBER': ['127871'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 420685638 " '],}


#list all models
list_models = [


'TRX680FA FourTrax Rincon',
'TRX680FGA FourTrax Rincon GPScape'


]

#Range of Years
years = list(range(2006, 2015))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make                              Model Vendor Code  \
# 0   utv/atv           TRX680FA FourTrax Rincon        NACH
# 1   utv/atv  TRX680FGA FourTrax Rincon GPScape        NACH
# 2   utv/atv           TRX680FA FourTrax Rincon        NACH
# 3   utv/atv  TRX680FGA FourTrax Rincon GPScape        NACH
# 4   utv/atv           TRX680FA FourTrax Rincon        NACH
# 5   utv/atv  TRX680FGA FourTrax Rincon GPScape        NACH
# 6   utv/atv           TRX680FA FourTrax Rincon        NACH
# 7   utv/atv  TRX680FGA FourTrax Rincon GPScape        NACH
# 8   utv/atv           TRX680FA FourTrax Rincon        NACH
# 9   utv/atv  TRX680FGA FourTrax Rincon GPScape        NACH
# 10  utv/atv           TRX680FA FourTrax Rincon        NACH
# 11  utv/atv  TRX680FGA FourTrax Rincon GPScape        NACH
# 12  utv/atv           TRX680FA FourTrax Rincon        NACH
# 13  utv/atv  TRX680FGA FourTrax Rincon GPScape        NACH
# 14  utv/atv           TRX680FA FourTrax Rincon        NACH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\25.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AT-01447'],
    
    'AD LIST NUMBER': ['127877'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 420685630, 420685631, 420685632 " '],}


#list all models
list_models = [


'TRX680FA FourTrax Rincon',
'TRX680FGA FourTrax Rincon GPScape'


]

#Range of Years
years = list(range(2015, 2024))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make                              Model Vendor Code  \
# 0   utv/atv           TRX680FA FourTrax Rincon        NACH
# 1   utv/atv  TRX680FGA FourTrax Rincon GPScape        NACH
# 2   utv/atv           TRX680FA FourTrax Rincon        NACH
# 3   utv/atv  TRX680FGA FourTrax Rincon GPScape        NACH
# 4   utv/atv           TRX680FA FourTrax Rincon        NACH
# 5   utv/atv  TRX680FGA FourTrax Rincon GPScape        NACH
# 6   utv/atv           TRX680FA FourTrax Rincon        NACH
# 7   utv/atv  TRX680FGA FourTrax Rincon GPScape        NACH
# 8   utv/atv           TRX680FA FourTrax Rincon        NACH
# 9   utv/atv  TRX680FGA FourTrax Rincon GPScape        NACH
# 10  utv/atv           TRX680FA FourTrax Rincon        NACH
# 11  utv/atv  TRX680FGA FourTrax Rincon GPScape        NACH
# 12  utv/atv           TRX680FA FourTrax Rincon        NACH
# 13  utv/atv  TRX680FGA FourTrax Rincon GPScape        NACH
# 14  utv/atv           TRX680FA FourTrax Rincon        NACH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\26.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AT-01449'],
    
    'AD LIST NUMBER': ['127878'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 2GU-85510-50, 5UH-81410-00, 3GG-85510-00, 3GG-85510-01, 4KB-85510-10, 4KB-85510-11, 4KB-85510-12 " '],}


#list all models
list_models = [

'YFM350 Bruin Auto 2x4',
'YFM350 Grizzly 4x4 Auto',
'YFM350 Grizzly Auto',
'YFM350 Grizzly IRS 4x4 Auto',
'YFM350 Raptor',
'YFM350 Wolverine',
'YFM350ER Moto-4',
'YFM350F Wolverine 4x4',
'YFM350FA Bruin Auto 4x4',
'YFM350FW Big Bear 4x4',
'YFM350U Big Bear 2x4',
'YFM350X Warrior',
'YFM400F Kodiak 4x4'


]

#Range of Years
years = list(range(1993, 1999))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make                        Model Vendor Code  \
# 0   utv/atv        YFM350 Bruin Auto 2x4        NACH
# 1   utv/atv      YFM350 Grizzly 4x4 Auto        NACH
# 2   utv/atv          YFM350 Grizzly Auto        NACH
# 3   utv/atv  YFM350 Grizzly IRS 4x4 Auto        NACH
# 4   utv/atv                YFM350 Raptor        NACH
# ..      ...                          ...         ...
# 73  utv/atv      YFM350FA Bruin Auto 4x4        NACH
# 74  utv/atv        YFM350FW Big Bear 4x4        NACH
# 75  utv/atv         YFM350U Big Bear 2x4        NACH
# 76  utv/atv              YFM350X Warrior        NACH
# 77  utv/atv           YFM400F Kodiak 4x4        NACH
#
#                       Vendor Name       MPN AD LIST NUMBER  \
# 0   NACHMAN INTERNATIONAL CO. LTD  AT-01449         127878
# 1   NACHMAN INTERNATIONAL CO. LTD  AT-01449         127878
# 2   NACHMAN INTERNATIONAL CO. LTD  AT-01449         127878
# 3   NACHMAN INTERNATIONAL CO. LTD  AT-01449         127878
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\27.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AT-01450'],
    
    'AD LIST NUMBER': ['127879'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 3089249, 3089546, 3089965, 3084974, 3086860, 420685630, 420685631, 420685632, 420685638, 420685921 " '],}


#list all models
list_models = [

'ATP 330',
'Magnum 330 2x4',
'Magnum 330 4x4',
'Trail Blazer 330',
'Trail Boss 330',
'LT250EF',
'LT250R QuadRacer',
'LT250S',
'LT300E',
'LT-F300F KingQuad 4x4'


]

#Range of Years
years = list(range(1990, 2010))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                  Model Vendor Code  \
# 0    utv/atv                ATP 330        NACH
# 1    utv/atv         Magnum 330 2x4        NACH
# 2    utv/atv         Magnum 330 4x4        NACH
# 3    utv/atv       Trail Blazer 330        NACH
# 4    utv/atv         Trail Boss 330        NACH
# ..       ...                    ...         ...
# 195  utv/atv                LT250EF        NACH
# 196  utv/atv       LT250R QuadRacer        NACH
# 197  utv/atv                 LT250S        NACH
# 198  utv/atv                 LT300E        NACH
# 199  utv/atv  LT-F300F KingQuad 4x4        NACH
#
#                        Vendor Name       MPN AD LIST NUMBER  \
# 0    NACHMAN INTERNATIONAL CO. LTD  AT-01450         127879
# 1    NACHMAN INTERNATIONAL CO. LTD  AT-01450         127879
# 2    NACHMAN INTERNATIONAL CO. LTD  AT-01450         127879
# 3    NACHMAN INTERNATIONAL CO. LTD  AT-01450         127879
# 4    NACHMAN INTERNATIONAL CO. LTD  AT-01450         127879
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\28.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AT-01436'],
    
    'AD LIST NUMBER': ['128103'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 28P-81410-00, 28P-81410-01, 3B4-81410-00 " '],}


#list all models
list_models = [

'YFZ450',
'YFZ450 Bill Balance Edition',
'YFZ450 SE',
'YFZ450R',
'YFZ450R SE',
'YFZ450X',
'YFZ450X Bill Balance'


]

#Range of Years
years = list(range(2004, 2010))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make                        Model Vendor Code  \
# 0   utv/atv                       YFZ450        NACH
# 1   utv/atv  YFZ450 Bill Balance Edition        NACH
# 2   utv/atv                    YFZ450 SE        NACH
# 3   utv/atv                      YFZ450R        NACH
# 4   utv/atv                   YFZ450R SE        NACH
# 5   utv/atv                      YFZ450X        NACH
# 6   utv/atv         YFZ450X Bill Balance        NACH
# 7   utv/atv                       YFZ450        NACH
# 8   utv/atv  YFZ450 Bill Balance Edition        NACH
# 9   utv/atv                    YFZ450 SE        NACH
# 10  utv/atv                      YFZ450R        NACH
# 11  utv/atv                   YFZ450R SE        NACH
# 12  utv/atv                      YFZ450X        NACH
# 13  utv/atv         YFZ450X Bill Balance        NACH
# 14  utv/atv                       YFZ450        NACH
# 15  utv/atv  YFZ450 Bill Balance Edition        NACH
# 16  utv/atv                    YFZ450 SE        NACH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\29.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AT-01437'],
    
    'AD LIST NUMBER': ['128104'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: "4013970, 4014402, 4014406, 4014839, 4015340,4014839,4015340,3084974, 3086860,327700001, 31100-F39-0002, 31120-004-000, 327700001,32101-19B10, 32101-19B30, 32101-45C00, 32101-48E00,32101-33H00, 32101-33H01,32101-38F00,32101-09F40, 32101-09F30,32101-09F00, 32101-09F01, 3430-011, 3430-045,32101-31G01, 32101-31G02" '],}


#list all models
list_models = [

'Sportsman 450 HO',
'Sportsman 450 HO EPS',
'Sportsman 450 HO Utility Edition',
'Sportsman 450 HO Utility',
'Sportsman 570',
'Sportsman 570 EPS',
'Sportsman 570 Touring',
'Sportsman 570 SP',
'Sportsman 570 SP Hunters Edition',
'Sportsman 570 Touring SP',
'Sportsman 570 X2 EPS',
'Sportsman 570 Touring EPS',
'Sportsman 570 Big Boss 6x6 EPS',
'Sportsman 570 EPS Utility Edition',
'Sportsman 570 6x6',
'Sportsman 570 Hunter Edition',
'Sportsman 570 Premium',
'Sportsman 570 Touring Premium',
'Sportsman 570 X2',
'Sportsman 570 Trail',
'Sportsman 570 Utility HD LE',
'Sportsman 570 Hunt Edition',
'Sportsman 570 Ultimate Trail LE',
'Sportsman 570 EPS Utility',
'Sportsman 570 Utility HD',
'Sportsman 570 Ride Command Limited Edition',
'Scrambler 850 XP HO',
'Scrambler 850 XP HO EPS LE',
'Scrambler 850',
'Sportsman 850 HO XP',
'Sportsman 850 HO XP EPS',
'Sportsman 850 HO XP EPS Browning LE',
'Sportsman 850 HO XP EPS Stealth Black LE',
'Sportsman 850 HO Touring EPS',
'Sportsman 850 HO Touring EPS Sunset Red LE',
'Sportsman 850 HO XP EPS Pearl White LE',
'Sportsman 850 HO Touring EPS Bronze Mist LE',
'Sportsman 850',
'Sportsman 850 SP',
'Sportsman 850 Touring SP',
'Sportsman 850 High Lifter Edition',
'Sportsman 850 Premium',
'Sportsman 850 Touring',
'Sportsman 850 Ultimate Trail',
'Scrambler 1000 XP EPS',
'Scrambler 1000 XP',
'Scrambler 1000 XP S',
'Scrambler 1000 XP S LE',
'Sportsman 1000 XP',
'Sportsman 1000 Touring XP',
'Sportsman 1000 XP Hunter Edition',
'Sportsman 1000 Touring XP Limited',
'Sportsman 1000 XP High Lifter Edition',
'Sportsman 1000 XP Premium',
'Sportsman 1000 XP S',
'Sportsman 1000 XP Hunt Edition',
'Sportsman 1000 XP Ultimate Trail',
'Sportsman 1000 XP Ride Command Edition',
'Ranger 900 XP',
'Ranger 900 XP EPS',
'Ranger 900 XP EPS Browning LE',
'Ranger 900 XP EPS LE',
'Ranger 900 XP LE',
'Ranger 900 XP Bronze Mist LE',
'Ranger 900 Crew',
'Ranger 900 Crew EPS',
'Ranger 900 Crew EPS LE',
'Ranger 900 XP Deluxe',
'Ranger 900 XP EPS Northstar Edition',
'Ranger 900 XP EPS Hunter Deluxe Edition',
'Ranger 900 XP EPS Deluxe',
'Ranger 900 XP EPS Hunter Edition',
'Ranger 900-6 Crew',
'Ranger 900-6 Crew EPS',
'General XP 4 1000 Deluxe',
'General XP 4 1000 Pursuit Edition',
'General XP 4 1000 Factory Custom Edition',
'General XP 4 1000 Troy Lee Designs Edition',
'General XP 4 1000 Trailhead Edition',
'General XP 4 1000 Deluxe Ride Command Edition',
'RZR 900 EPS LE',
'RZR 900',
'RZR 900 XC Edition',
'RZR 900 EPS Trail',
'RZR 900 EPS XC Edition',
'RZR 900 EPS Trail Fox Edition LE',
'RZR 900 EPS',
'RZR 900 Premium',
'RZR 900 Fox Edition',
'RZR XP 4 1000 EPS',
'RZR XP 4 1000 EPS High Lifter Edition',
'RZR XP 4 1000 EPS Ride Command Edition',
'RZR XP 4 1000 EPS Dynamix Edition',
'RZR XP 4 1000',
'RZR XP 4 1000 Premium',
'RZR XP 4 1000 Limited Edition',
'RZR XP 4 1000 High Lifter',
'RZR XP 4 1000 Sport',
'General 1000 EPS',
'General 1000 EPS Deluxe',
'General 1000 EPS Hunter Edition',
'General 1000 EPS Ride Command Edition',
'General 1000 EPS Premium',
'General 1000 EPS Limited Edition',
'General 1000',
'General 1000 Premium',
'General 1000 Deluxe',
'General 1000 Sport',
'General 1000 Deluxe Ride Command Edition',
'Ranger 1000',
'Ranger 1000 EPS',
'Ranger 1000 Premium',
'Ranger 1000 Premium + Winter Prep Package',
'Ranger XP 1000 EPS Northstar HVAC Edition',
'Ranger XP 1000 EPS High Lifter Edition',
'Ranger XP 1000 EPS Ranch Edition',
'Ranger XP 1000 EPS Hunter Edition',
'Ranger XP 1000 EPS',
'Ranger XP 1000',
'Ranger XP 1000 EPS Premium',
'Ranger XP 1000 EPS 20th Anniversary',
'Ranger XP 1000 Premium',
'Ranger XP 1000 NorthStar Edition',
'Ranger XP 1000 High Lifter Edition',
'Ranger XP 1000 Texas Edition',
'Ranger XP 1000 NorthStar Premium',
'Ranger XP 1000 NorthStar Edition Trail Boss',
'Ranger XP 1000 NorthStar Ultimate',
'Ranger XP 1000 Trail Boss',
'Ranger XP 1000 Waterfowl Edition',
'Ranger XP 1000 Big Game Edition',
'RZR Trail Ultimate',
'RZR Trail S 1000 Premium',
'RZR Trail S 900 Sport',
'RZR Trail Premium',
'RZR Trail Sport',
'RZR Trail S 1000 Ultimate',
'RZR XP 1000 EPS LE',
'RZR XP 1000 EPS',
'RZR XP 1000 EPS High Lifter Edition',
'RZR XP 1000 EPS Desert Edition',
'RZR XP 1000 EPS Fox Edition',
'RZR XP 1000 EPS Velocity Blue LE',
'RZR XP 1000 EPS Gold Matte Metallic LE',
'RZR XP 1000 EPS Ride Command Edition',
'RZR XP 1000 EPS Trails and Rock Edition',
'RZR XP 1000 EPS DYNAMIX Edition',
'RZR XP 1000',
'RZR XP 1000 Premium',
'RZR XP 1000 Limited Edition',
'RZR XP 1000 Trails & Rocks',
'RZR XP 1000 High Lifter',
'RZR XP 1000 Sport',
'M1400',
'RZR RS1',
'ACE 500',
'Ranger 500 Crew',
'Ranger 500 Crew LE',
'Ranger 500 EFI',
'Ranger 500 EFI LE',
'Ranger 500',
'Sportsman ACE 570',
'Sportsman ACE 570 SP',
'ACE 570 SP',
'ACE 570',
'ACE 570 EPS',
'Ranger 570',
'Ranger 570 EPS LE',
'Ranger 570 Crew',
'Ranger 570 Crew EPS LE',
'Ranger 570 EPS',
'Ranger 570 EPS Full-Size',
'Ranger 570 Full-Size',
'Ranger 570 Crew EPS',
'Ranger 570 Crew Full-Size',
'Ranger 570 Crew EPS Full-Size',
'Ranger 570 EPS Hunter Edition',
'Ranger 570 Premium',
'Ranger RZR 570',
'Ranger RZR 570 EPS Trail LE',
'RZR 570',
'RZR 570 EPS Trail LE',
'RZR 570 EPS LE',
'RZR 570 EPS Trail',
'RZR 570 EPS',
'RZR 570 Premium',
'RZR 570 Trail',
'RZR 4 900 EPS LE',
'RZR 4 900 EPS',
'ACE 900 SP',
'ACE 900 XC'

]

#Range of Years
years = list(range(2013, 2024))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#          Make                             Model Vendor Code  \
# 0     utv/atv                  Sportsman 450 HO        NACH
# 1     utv/atv              Sportsman 450 HO EPS        NACH
# 2     utv/atv  Sportsman 450 HO Utility Edition        NACH
# 3     utv/atv          Sportsman 450 HO Utility        NACH
# 4     utv/atv                     Sportsman 570        NACH
# ...       ...                               ...         ...
# 2096  utv/atv                     RZR 570 Trail        NACH
# 2097  utv/atv                  RZR 4 900 EPS LE        NACH
# 2098  utv/atv                     RZR 4 900 EPS        NACH
# 2099  utv/atv                        ACE 900 SP        NACH
# 2100  utv/atv                        ACE 900 XC        NACH
#
#                         Vendor Name       MPN AD LIST NUMBER  \
# 0     NACHMAN INTERNATIONAL CO. LTD  AT-01437         128104
# 1     NACHMAN INTERNATIONAL CO. LTD  AT-01437         128104
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\30.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['utv/atv'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN': ['AT-01438'],
    
    'AD LIST NUMBER': ['128105'],
    
    'VENDOR NOTES': ['"*** AT-01450 ALSO FITS ON MC/ MX APPLICATION, PLEASE INQUIRE FOR DETAILS. *** AC-01973 NOTE: THERE ARE TWO POSSILBLE STATORS FOR 04-05 SPORTSMAN 600 & 700 MACHINES, THIS ONE HAS 18 CHARGE POLES, THE OTHER HAS 11 CHARGE POLES, PLEASE ENSURE YOUR MACHINE HAS 18 CHARGING POLES. *** AC-01958 NOTE: 1995-99  YFM 350 WOLVERINE HAS TWO POSSIBLE STATORS, THIS STATOR HAS AND EXTERNAL DIAMETER OF 93MM.   ;OEM: 420685630, 420685631, 420685632, 420685638 " '],}


#list all models
list_models = [

'TRX500FA FourTrax Foreman Rubicon',
'TRX500FGA FourTrax Foreman Rubicon GPScape',
'TRX500FE FourTrax Foreman 4x4 ES',
'TRX500FM FourTrax Foreman 4x4',
'TRX500FPE FourTrax Foreman 4x4 ES w/Power Steering',
'TRX500FPM FourTrax Foreman 4x4 w/ Power Steering',
'TRX500TM FourTrax Foreman',
'TRX500FPA FourTrax Foreman Rubicon with EPS',
'TRX500FM1 FourTrax Foreman 4x4',
'TRX500FE1 FourTrax Foreman 4x4 ES',
'TRX500FM2 FourTrax Foreman 4x4 with EPS',
'TRX500FE2 FourTrax Foreman 4x4 ES with EPS',
'TRX500FM5 FourTrax Foreman Rubicon',
'TRX500FM6 FourTrax Foreman Rubicon EPS',
'TRX500FM6D FourTrax Foreman Rubicon EPS DLX',
'TRX500FA5 FourTrax Foreman Rubicon Auto DCT',
'TRX500FA6 FourTrax Foreman Rubicon Auto DCT EPS',
'TRX500FA6D FourTrax Foreman Rubicon Auto DCT EPS D',
'TRX500FA7 FourTrax Foreman Rubicon Auto DCT EPS DL',
'TRX500FM7 FourTrax Foreman Rubicon EPS DLX'


]

#Range of Years
years = list(range(2005, 2015))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                                              Model Vendor Code  \
# 0    utv/atv                  TRX500FA FourTrax Foreman Rubicon        NACH
# 1    utv/atv         TRX500FGA FourTrax Foreman Rubicon GPScape        NACH
# 2    utv/atv                   TRX500FE FourTrax Foreman 4x4 ES        NACH
# 3    utv/atv                      TRX500FM FourTrax Foreman 4x4        NACH
# 4    utv/atv  TRX500FPE FourTrax Foreman 4x4 ES w/Power Stee...        NACH
# ..       ...                                                ...         ...
# 195  utv/atv        TRX500FA5 FourTrax Foreman Rubicon Auto DCT        NACH
# 196  utv/atv    TRX500FA6 FourTrax Foreman Rubicon Auto DCT EPS        NACH
# 197  utv/atv  TRX500FA6D FourTrax Foreman Rubicon Auto DCT E...        NACH
# 198  utv/atv  TRX500FA7 FourTrax Foreman Rubicon Auto DCT EP...        NACH
# 199  utv/atv         TRX500FM7 FourTrax Foreman Rubicon EPS DLX        NACH
#
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\BERN\09_SECTION 01 - STATOR ( 01-24-24 )\Merge\31.csv"
final_df.to_csv(file_path, index = False)
